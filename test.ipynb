# %% [markdown]
# **REMEMBER: Restart this notebook to close connection to `sparkifydb`**
#
# Each time you run the cells below, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %% [markdown]
# This notebook was run with 6 sample data files:
#
# ```
# data/
# ├── log_data
# │   └── 2018
# │       └── 11
# │           ├── 2018-11-01-events.json
# │           └── 2018-11-02-events.json
# └── song_data
#     └── A
#         ├── A
#         │   └── A
#         │       ├── TRAAAAW128F429D538.json
#         │       └── TRAAABD128F429CF47.json
#         └── B
#             └── A
#                 ├── TRABACN128F425B784.json
#                 └── TRABAFJ128F42AF24E.json
# ```

# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songs ORDER BY song_id LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 4 rows affected.
# [('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148.03546),
#  ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  ('SOPVXLX12A8C1402D5', 'Larger Than Life', 'AR3JMC51187B9AE49D', 1999, 236.25098),
#  ('SOQLGFP12A58A7800E', 'OAKtown', 'ARD7TVE1187B99BFB1', 0, 259.44771)]

# %%
# %sql SELECT * FROM artists ORDER BY artist_id LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 3 rows affected.
# [('AR3JMC51187B9AE49D', 'Backstreet Boys', 'Orlando, FL', 28.53823, -81.37739),
#  ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892)]

# %%
# %sql SELECT * FROM users ORDER BY user_id LIMIT 30;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 22 rows affected.
# [(3, 'Isaac', 'Valdez', 'M', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (15, 'Lily', 'Koch', 'F', 'paid'),
#  (17, 'Makinley', 'Jones', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (48, 'Marina', 'Sutton', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (66, 'Kevin', 'Arellano', 'M', 'free'),
#  (71, 'Ayleen', 'Wise', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'free'),
#  (83, 'Stefany', 'White', 'F', 'free'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (89, 'Kynnedi', 'Sanchez', 'F', 'free'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free')]

# %%
# %sql SELECT * FROM time ORDER BY timestamp LIMIT 30;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 30 rows affected.
# [(1541106106796, datetime.datetime(2018, 11, 1, 18, 1, 46, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)), 21, 1, 44, 11, 2018, 3),
#  (1541106352796, datetime.datetime(2018, 11, 1, 18, 5, 52, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)), 21, 1, 44, 11, 2018, 3),
#  (1541106496796, datetime.datetime(2018, 11, 1, 18, 8, 16, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)), 21, 1, 44, 11, 2018, 3),
#  (1541106673796, datetime.datetime(2018, 11, 1, 18, 11, 13, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)), 21, 1, 44, 11, 2018, 3),
#  (1541107053796, datetime.datetime(2018, 11, 1, 18, 17, 33, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-180, name=None)), 21, 1, 44, 11, 2018, 3),
# ...

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, 1541106106796, 8, 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (2, 1541106352796, 8, 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (3, 1541106496796, 8, 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (4, 1541106673796, 8, 'free', None, None, 139, 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM songplays WHERE song_id IS NOT NULL OR artist_id IS NOT NULL LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []
